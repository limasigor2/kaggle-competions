# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
# para as colunas que podiam ser feitos gráficos de dispersão foram feitos
# as colunas Kitchen e Bedroom não estavam na data frame

# %%
data = pd.read_csv("../dados/train.csv")

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1460.000000  1460.000000    1460.000000  1460.000000
# mean       ...          94.244521    46.660274      21.954110     3.409589
# std        ...         125.338794    66.256028      61.119149    29.317331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 38 columns]

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
sns.distplot(data['SalePrice']);

# %%
#correlation matrixBsmtFinSF2
new = data[['OverallCond','MasVnrArea','BsmtFinSF1','BsmtFinSF2',
            'YearRemodAdd','MSSubClass','LotFrontage','LotArea',
            'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
            'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
            'GarageCars', 'OpenPorchSF', 'FullBath', 'HalfBath',
            'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageArea',
            'WoodDeckSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch',
            'PoolArea', 'MiscVal', 'MoSold', 'YrSold',
            'YearBuilt', 'OverallQual', 'SalePrice']].copy()

corrmat = new.corr()
f, ax = plt.subplots(figsize=(60, 30))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
# OveraallQual, GrliveArea, YearBuilt, GarageArea, GarageYrBlt, TotRmsAbvGrd, Fireplaces
# FullBath, GarageCars, TotalBsmtSF, 1stFlrSF, YearRemodAdd

# %%
plt.scatter(data.MSSubClass,data.SalePrice)

# %%
plt.scatter(data.LotFrontage, data.SalePrice)

# %%
plt.scatter(data.LotArea, data.SalePrice)

# %%
plt.scatter(data.OverallQual, data.SalePrice)

# %%
plt.scatter(data.OverallCond, data.SalePrice)

# %%
plt.scatter(data.YearBuilt, data.SalePrice)

# %%
plt.scatter(data.YearRemodAdd, data.SalePrice)

# %%
plt.scatter(data.MasVnrArea, data.SalePrice)

# %%
plt.scatter(data.BsmtFinSF1, data.SalePrice)

# %%
plt.scatter(data.BsmtFinSF2, data.SalePrice)

# %%
plt.scatter(data.BsmtUnfSF, data.SalePrice)

# %%
plt.scatter(data.TotalBsmtSF, data.SalePrice)

# %%
plt.scatter(data['1stFlrSF'], data.SalePrice)

# %%
plt.scatter(data['2ndFlrSF'], data.SalePrice)

# %%
plt.scatter(data.LowQualFinSF, data.SalePrice)

# %%
plt.scatter(data.GrLivArea, data.SalePrice)

# %%
plt.scatter(data.BsmtFullBath, data.SalePrice)

# %%
plt.scatter(data.BsmtHalfBath, data.SalePrice)

# %%
plt.scatter(data.FullBath, data.SalePrice)

# %%
plt.scatter(data.HalfBath, data.SalePrice)

# %%
plt.scatter(data.Bedroom, data.SalePrice)
#data não contem Bedroom
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-a74f7ddd3353> in <module>()
# ----> 1 plt.scatter(data.Bedroom, data.SalePrice)
#       2 #data não contem Bedroom
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Bedroom'

# %%
plt.scatter(data.Kitchen, data.SalePrice)
#data não contem Kitchen
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-ef1fd2078c49> in <module>()
# ----> 1 plt.scatter(data.Kitchen, data.SalePrice)
#       2 #data não contem Kitchen
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Kitchen'

# %%
plt.scatter(data.TotRmsAbvGrd, data.SalePrice)

# %%
plt.scatter(data.Fireplaces, data.SalePrice)

# %%
plt.scatter(data.GarageYrBlt, data.SalePrice)

# %%
plt.scatter(data.GarageCars, data.SalePrice)

# %%
plt.scatter(data.GarageArea, data.SalePrice)

# %%
plt.scatter(data.WoodDeckSF, data.SalePrice)

# %%
plt.scatter(data.OpenPorchSF, data.SalePrice)

# %%
plt.scatter(data.EnclosedPorch, data.SalePrice)

# %%
plt.scatter(data['3SsnPorch'], data.SalePrice)

# %%
plt.scatter(data['PoolArea'], data.SalePrice)

# %%
plt.scatter(data['MiscVal'], data.SalePrice)

# %%
plt.scatter(data['MoSold'], data.SalePrice)

# %%
plt.scatter(data['YrSold'], data.SalePrice)

# %%
# %store data
# Out:
# Stored 'data' (DataFrame)
